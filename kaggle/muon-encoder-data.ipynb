# %% [markdown]
# # muon-encoder: data preparation
#
# CPU-only notebook (no GPU quota used). Settings: **Internet on**, **Accelerator: None**.
#
# Run with **Save Version → Save & Run All**. The output (`data/train.bin`, `data/val.bin`) becomes the input of the training notebook.

# %%
REPO = "https://github.com/Jakevanveen123/muon-encoder"
# !git clone -q $REPO code
# %cd code
# !pip install -q -U transformers datasets

# %%
# 7e8 train tokens covers the 2x AdamW budget at 17M (2 * 20 * 16.9M = 676M)
# !python prepare_data.py --train_tokens 7e8 --val_tokens 2e7 --out_dir /kaggle/working/data

# %%
# !ls -lh /kaggle/working/data
